# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BackDoor
# Out:
# /content/drive/MyDrive/Colab Notebooks/BackDoor

# %%
# !pip install torch-dct==0.1.6
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !python main.py --epochs 20
# Out:
# Device:  cuda
# Expt: ../exps/lenet/2025-03-20T22-31-45.6946214hq7fzx4
# RunID: 2025-03-20T22-31-45.694621
# The command that ran this script: main.py --epochs 20
# Namespace(experiment='lenet',
# dataset='MNIST',
# model='lenet',
# nb_classes=10,
# load_local=False,
# save_dir='',
# loss='ce',
# optimizer='sgd',
# epochs=20,
# batch_size=64,
# num_workers=0,
# lr=0.01,
# download=False,
# data_path='./data/',
# device='cpu',
# seed=11,
# no_cuda=False,
# poisoning_rate=0.1,
# trigger_label=1,
# trigger_path='./triggers/trigger_white.png',
# trigger_size=5,
# cuda=True)
#
# # load dataset: MNIST
# Transform =  Compose(
#     ToTensor()
#     Normalize(mean=(0.0,), std=(1.0,))
# )
# Poison 6000 over 60000 samples ( poisoning rate 0.1)
# Number of the class = 10
# Dataset MNISTPoison
#     Number of datapoints: 60000
#     Root location: ./data/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
# ...

# %%
# !python main.py --load_local --save-dir '/content/drive/MyDrive/Colab Notebooks/exps/lenet/2025-03-20T22-31-45.6946214hq7fzx4'
# Out:
# Device:  cuda
# Expt: /content/drive/MyDrive/Colab Notebooks/exps/lenet/2025-03-20T22-31-45.6946214hq7fzx4
# RunID: 2025-03-20T22-47-55.345188
# The command that ran this script: main.py --load_local --save-dir /content/drive/MyDrive/Colab Notebooks/exps/lenet/2025-03-20T22-31-45.6946214hq7fzx4
# Namespace(experiment='lenet',
# dataset='MNIST',
# model='lenet',
# nb_classes=10,
# load_local=True,
# save_dir='/content/drive/MyDrive/Colab Notebooks/exps/lenet/2025-03-20T22-31-45.6946214hq7fzx4',
# loss='ce',
# optimizer='sgd',
# epochs=100,
# batch_size=64,
# num_workers=0,
# lr=0.01,
# download=False,
# data_path='./data/',
# device='cpu',
# seed=11,
# no_cuda=False,
# poisoning_rate=0.1,
# trigger_label=1,
# trigger_path='./triggers/trigger_white.png',
# trigger_size=5,
# cuda=True)
#
# # load dataset: MNIST
# Transform =  Compose(
#     ToTensor()
#     Normalize(mean=(0.0,), std=(1.0,))
# )
# Poison 6000 over 60000 samples ( poisoning rate 0.1)
# Number of the class = 10
# ...

# %%
# !python main.py --epochs 20 --poisoning_rate 0.0
# Out:
# Device:  cuda
# Expt: ../exps/lenet/2025-03-20T23-03-43.600201xoevk8io
# RunID: 2025-03-20T23-03-43.600201
# The command that ran this script: main.py --epochs 20 --poisoning_rate 0.0
# Namespace(experiment='lenet',
# dataset='MNIST',
# model='lenet',
# nb_classes=10,
# load_local=False,
# save_dir='',
# loss='ce',
# optimizer='sgd',
# epochs=20,
# batch_size=64,
# num_workers=0,
# lr=0.01,
# download=False,
# data_path='./data/',
# device='cpu',
# seed=11,
# no_cuda=False,
# poisoning_rate=0.0,
# trigger_label=1,
# trigger_path='./triggers/trigger_white.png',
# trigger_size=5,
# cuda=True)
#
# # load dataset: MNIST
# Transform =  Compose(
#     ToTensor()
#     Normalize(mean=(0.0,), std=(1.0,))
# )
# Poison 0 over 60000 samples ( poisoning rate 0.0)
# Number of the class = 10
# Dataset MNISTPoison
#     Number of datapoints: 60000
#     Root location: ./data/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
# ...
